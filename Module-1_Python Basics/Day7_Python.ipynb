# %% [markdown]
# ## Two types of Error occurs in python.
#
# * Syntax errors
# * Logical errors (Exceptions)

# %% [markdown]
# ### "Exception Description"
#
# * **IndexError**: When the wrong index of a list is retrieved.
# * **AssertionError**: It occurs when the assert statement fails.
# * **AttributeError**: It occurs when an attribute assignment is failed.
# * **ImportError**: It occurs when an imported module is not found.
# * **KeyError**: When the key of the dictionary is not found.
# * **NameError**: It occurs when the variable is not defined.
# * **MemoryError**: It occurs when a program runs out of memory.
# * **TypeError**: It occurs when a function and operation are applied in an incorrect type.
# * **ZeroDivisionError**: division by zero

# %% [markdown]
# ```python
# try:
#     # Some Code....
#     # LOC which has potential to cause error
# except:
#     # optional block
#     # Handling of exception (if required)
# finally:
#     # Some code .....(always executed)

# %%
try:
    a = int(input("Enter No 1: "))
    b = int(input("Enter No 2: "))
    
    # Division
    c = a / b
    print("Div is: ", c)
    # IndexError
    # AttributeError
except ZeroDivisionError:
    print("You can't divide by zero!!")
except ValueError:
    print("Please enter a valid number!!")
finally:
    print("Always executed!!!")

# %% [markdown]
# * try: Test a block of code for errors.
#
# * except: Handle the error (executed only if an error occurs in the try block).
#
# * finally: Execute code regardless of the result of the try- and except-blocks.
