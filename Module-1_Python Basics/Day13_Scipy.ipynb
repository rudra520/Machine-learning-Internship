# %% [markdown]
# # Scipy

# %%
Scipy ---> Scientific Python.

# %%
it helps us to provide more utility functions for Optimization of Stats and signal processing.

# %%
import scipy

# %%
-----> Constants
-----> Stats

# %%
from scipy import stats

# %%
from scipy import constants

# %%
constants.pi
# Out:
# 3.141592653589793

# %%
constants.kilo
# Out:
# 1000.0
